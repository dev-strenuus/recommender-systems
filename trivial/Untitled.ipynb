# %%
import pandas as pd
import numpy as np
df = pd.read_csv('input/train.csv')
size = df.loc[df['track_id'].idxmax()]['track_id']
print(size)
playlistsForTrack = np.empty([size], dtype=set)
for i in range(size):
    playlistsForTrack[i] = set(df[df['track_id']==i]['playlist_id'])
bestSimilarTracks = np.empty((size), dtype=object)
print(size)
print(bestSimilarTracks)
for i in range(size):
    print(i)
    bestSimilarTracks[i] = np.empty((size, 2), dtype=object)
    bestSimilarTracks[i][i] = [0,i]
    for j in range(i):
        similarity = len(playlistsForTrack[i] & playlistsForTrack[j])/min((len(playlistsForTrack[i]), len(playlistsForTrack[j])))
        bestSimilarTracks[i][j] = [-1*similarity, j]
    for j in range(i+1, size):
        similarity = len(playlistsForTrack[i] & playlistsForTrack[j])/min((len(playlistsForTrack[i]), len(playlistsForTrack[j])))
        bestSimilarTracks[i][j] = [-1*similarity, j]
    bestSimilarTracks[i] = np.partition(bestSimilarTracks[i], 10, axis=0)[0:10]
    bestSimilarTracks[i] = bestSimilarTracks[i][bestSimilarTracks[i][:,0] !=0]#[:,1]
    bestSimilarTracks[i][:,0] = -1*bestSimilarTracks[i][:,0]
    print(bestSimilarTracks[i])
# Out:
# 20634
# 20634
# [None None None ... None None None]
# 0
# [[0.3333333333333333 0]
#  [0.3076923076923077 1]
#  [0.3076923076923077 2]
#  [0.2857142857142857 3]
#  [0.2857142857142857 4]
#  [0.2692307692307692 5]
#  [0.2692307692307692 6]
#  [0.2692307692307692 7]
#  [0.2692307692307692 8]
#  [0.26666666666666666 9]]
# 1
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [0.7272727272727273 3]
#  [0.5294117647058824 4]
#  [0.5294117647058824 5]
#  [0.5 6]
#  [0.5 7]
#  [0.5 8]
#  [0.5 9]]
# 2
# [[1.0 0]
#  [0.5 1]
#  [0.5 2]
#  [0.5 3]
#  [0.5 4]
#  [0.5 5]
#  [0.5 6]
#  [0.5 7]
#  [0.5 8]
#  [0.5 9]]
# 3
# [[0.625 0]
#  [0.5714285714285714 1]
#  [0.5 2]
#  [0.375 3]
#  [0.375 4]
#  [0.25 5]
#  [0.25 6]
#  [0.25 7]
#  [0.25 8]
#  [0.25 9]]
# 4
# [[1.0 0]
#  [0.9166666666666666 1]
#  [0.9166666666666666 2]
#  [0.9166666666666666 3]
#  [0.9166666666666666 4]
#  [0.9166666666666666 5]
#  [0.9166666666666666 6]
#  [0.9 7]
#  [0.8333333333333334 8]
#  [0.8333333333333334 9]]
# 5
# [[1.0 0]
#  [0.5 1]
#  [0.5 2]
#  [0.5 3]
#  [0.4 4]
#  [0.34285714285714286 5]
#  [0.3333333333333333 6]
#  [0.3333333333333333 7]
#  [0.3333333333333333 8]
#  [0.3333333333333333 9]]
# 6
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [1.0 3]
#  [1.0 4]
#  [1.0 5]
#  [1.0 6]
#  [1.0 7]
#  [1.0 8]
#  [1.0 9]]
# 7
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [1.0 3]
#  [1.0 4]
#  [1.0 5]
#  [1.0 6]
#  [1.0 7]
#  [1.0 8]
#  [0.875 9]]
# 8
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [1.0 3]
#  [1.0 4]
#  [1.0 5]
#  [0.5 6]
#  [0.5 7]
#  [0.5 8]
#  [0.3333333333333333 9]]
# 9
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [0.5 3]
#  [0.5 4]
#  [0.5 5]
#  [0.5 6]
#  [0.5 7]
#  [0.5 8]
#  [0.5 9]]
# 10
# [[0.5 0]
#  [0.5 1]
#  [0.5 2]
#  [0.45454545454545453 3]
#  [0.4444444444444444 4]
#  [0.4444444444444444 5]
#  [0.4444444444444444 6]
#  [0.4444444444444444 7]
#  [0.4 8]
#  [0.3888888888888889 9]]
# 11
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [1.0 3]
#  [1.0 4]
#  [1.0 5]
#  [1.0 6]
#  [1.0 7]
#  [1.0 8]
#  [1.0 9]]
# 12
# [[1.0 0]
#  [1.0 1]
#  [0.3333333333333333 2]
#  [0.3333333333333333 3]
#  [0.32 4]
#  [0.26 5]
#  [0.26 6]
#  [0.25 7]
#  [0.25 8]
#  [0.23076923076923078 9]]
# 13
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [1.0 3]
#  [1.0 4]
#  [1.0 5]
#  [1.0 6]
#  [1.0 7]
#  [1.0 8]
#  [1.0 9]]
# 14
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [1.0 3]
#  [1.0 4]
#  [1.0 5]
#  [1.0 6]
#  [1.0 7]
#  [1.0 8]
#  [1.0 9]]
# 15
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [0.5 3]
#  [0.5 4]
#  [0.5 5]
#  [0.5 6]
#  [0.5 7]
#  [0.44339622641509435 8]
#  [0.4 9]]
# 16
# [[1.0 0]
#  [1.0 1]
#  [0.5 2]
#  [0.5 3]
#  [0.5 4]
#  [0.3333333333333333 5]
#  [0.25 6]
#  [0.25 7]
#  [0.25 8]
#  [0.25 9]]
# 17
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [1.0 3]
#  [1.0 4]
#  [1.0 5]
#  [1.0 6]
#  [1.0 7]
#  [0.5 8]
#  [0.5 9]]
# 18
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [1.0 3]
#  [1.0 4]
#  [1.0 5]
#  [1.0 6]
#  [1.0 7]
#  [1.0 8]
#  [1.0 9]]
# 19
# [[1.0 0]
#  [0.5 1]
#  [0.5 2]
#  [0.36363636363636365 3]
#  [0.3333333333333333 4]
#  [0.3333333333333333 5]
#  [0.3333333333333333 6]
#  [0.3333333333333333 7]
#  [0.2857142857142857 8]
#  [0.2727272727272727 9]]
# 20
# [[1.0 0]
#  [1.0 1]
#  [0.5 2]
#  [0.5 3]
#  [0.5 4]
#  [0.5 5]
#  [0.5 6]
#  [0.5 7]
#  [0.5 8]
#  [0.4626865671641791 9]]
# 21
# [[1.0 0]
#  [0.5 1]
#  [0.5 2]
#  [0.5 3]
#  [0.3893805309734513 4]
#  [0.35398230088495575 5]
#  [0.34513274336283184 6]
#  [0.3333333333333333 7]
#  [0.3333333333333333 8]
#  [0.3185840707964602 9]]
# 22
# [[0.3333333333333333 0]
#  [0.25 1]
#  [0.25 2]
#  [0.25 3]
#  [0.25 4]
#  [0.20833333333333334 5]
#  [0.20833333333333334 6]
#  [0.2 7]
#  [0.16666666666666666 8]
#  [0.16666666666666666 9]]
# 23
# [[0.5 0]
#  [0.5 1]
#  [0.5 2]
#  [0.5 3]
#  [0.5 4]
#  [0.5 5]
#  [0.4 6]
#  [0.3902439024390244 7]
#  [0.3877551020408163 8]
#  [0.3333333333333333 9]]
# 24
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [1.0 3]
#  [0.5 4]
#  [0.5 5]
#  [0.5 6]
#  [0.5 7]
#  [0.5 8]
#  [0.40540540540540543 9]]
# 25
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [1.0 3]
#  [1.0 4]
#  [1.0 5]
#  [1.0 6]
#  [0.75 7]
#  [0.6666666666666666 8]
#  [0.6666666666666666 9]]
# 26
# [[1.0 0]
#  [1.0 1]
#  [1.0 2]
#  [1.0 3]
#  [1.0 4]
#  [1.0 5]
#  [0.5 6]
#  [0.5 7]
#  [0.5 8]
#  [0.5 9]]
# 27
# [[1.0 0]
#  [0.5 1]
#  [0.5 2]
#  [0.5 3]
#  [0.5 4]
#  [0.3333333333333333 5]
#  [0.3333333333333333 6]
#  [0.3333333333333333 7]
#  [0.3333333333333333 8]
#  [0.3333333333333333 9]]
# 28
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-40a8fe1e95c9> in <module>()
#      18         bestSimilarTracks[i][j] = [-1*similarity, j]
#      19     for j in range(i+1, size):
# ---> 20         similarity = len(playlistsForTrack[i] & playlistsForTrack[j])/min((len(playlistsForTrack[i]), len(playlistsForTrack[j])))
#      21         bestSimilarTracks[i][j] = [-1*similarity, j]
#      22     bestSimilarTracks[i] = np.partition(bestSimilarTracks[i], 10, axis=0)[0:10]
#
# KeyboardInterrupt:

# %%
df1 = pd.read_csv('input/target_playlists.csv')

# %%
playlists = np.array(df1['playlist_id'])
print(playlists)
# Out:
# [    7    25    29 ... 50416 50417 50424]

# %%
for playlist in playlists:
    tracks = np.array(df[df['playlist_id']==playlist]['track_id'])
    best = {}
    for track in tracks:
        for similar in bestSimilarTracks[track]:
            if similar[1] in best:
                best[similar[1]]+=similar[0]
            else:
                best[similar[1]]=similar[0]
    best = np.array(best)
    best = np.partial
    print(best)
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-e79ad0e33d98> in <module>()
#       3     best = {}
#       4     for track in tracks:
# ----> 5         for similar in bestSimilarTracks[track]:
#       6             if similar[1] in best:
#       7                 best[similar[1]]+=similar[0]
#
# TypeError: 'NoneType' object is not iterable
